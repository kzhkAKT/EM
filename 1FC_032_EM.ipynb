# %% [markdown]
# <a href="https://colab.research.google.com/github/kzhkAKT/ErgyMtrlScience/blob/draft/1FC_032_EM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 電極電位

# %% [markdown]
# ## 標準電極電位 $E^\circ$, Standard electrode potential
# $\require{mhchem}$
#
# \begin{align*}
# \ce{O} + n \ce{e- <=> R}&
# \end{align*}
#
# - ${\rm O}$: oxidant/酸化体(電子を受け取る)
# - ${\rm R}$: reductant/還元体(電子を受け取った後)
#
# この反応の電位で, ${\rm O/R}$が 基準状態($a=1$)となる電位を  **標準電極電位** $E^\circ_{\ce{(O/R)}}$

# %% [markdown]
# ## 電位の原点
# (負の電荷を持つ)電子$\ce{e-}$が上の反応で $E^\circ_{\rm O/R}$ の影響を受けるので, 電子授受平衡を考えると
# \begin{align*}
# \Delta_{\rm f}G^\circ(\ce{O}) + (-n\mathcal{F})E^\circ_{\ce{(O/R)}}
# = \Delta_{\rm f}G^\circ(\ce{R})
# \end{align*}
# この反応を利用して, 電位測定の基準となる電位を周期律表で最も軽い元素を利用した
# 水素分子 $\ce{H2}$ と 水素イオン $\ce{H+}$ を利用して定義する.
# 水素の標準生成ギブスエネルギー$\Delta_{\rm f} G(\ce{H2})$ は中性単体($\ce{H2}$)では(単体で安定しているので) ゼロ と考えました. さらに水素イオン $\ce{H+}$ の $\Delta_{\rm f} G(\ce{H+})$ もゼロにとると. $\ce{O=2H+, R=H2}$ のとき $E^\circ_{\ce{2H+/H2}} =E^\circ=0$
#
# 標準**水素**電極電位(Standard Hydrogen Electrode) では次の反応の電位を基準(ゼロ)として他の電位を相対的に決めます.
# \begin{align*}
# \ce{2H+} + \ce{2e- <=> H2}&
# \end{align*}
# この定義は $\ce{H+}$ で $a_{\ce{H+}}=1$($[\ce{H+}]={\rm 1 mol/L}, {\rm pH=0}$) の水溶液に白金電極を利用した装置で測定できます.

# %% [markdown]
# $\ce{H2}$の燃焼反応では
# \begin{align*}
# &\ce{2H+ + 2e- <=> H2}&\\
# &\ce{1/2O2 + 2H+ + 2e- <=> H2O}&
# \end{align*}
#
# 上段の式が $E^\circ=0,$ 下段の式が$E^\circ=+1.23{\rm \ V}$ となり, $E^\circ = {\rm +1.23 V} vs. \text{SHE}$ と表現できます.

# %%
#@title sopontaneous: ε-E
# %%svg
<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="441px" viewBox="-0.5 -0.5 441 263" content="&lt;mxfile host=&quot;www.draw.io&quot; modified=&quot;2020-06-03T06:54:02.480Z&quot; agent=&quot;5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36&quot; etag=&quot;9qJga-ac7mOXAGmQmARF&quot; version=&quot;13.1.12&quot; type=&quot;google&quot;&gt;&lt;diagram id=&quot;CzV_nv0xv4kslDsghHYD&quot; name=&quot;Page-1&quot;&gt;...&lt;/diagram&gt;&lt;/mxfile&gt;" onclick="(function(svg){var src=window.event.target||window.event.srcElement;while (src!=null&amp;&amp;src.nodeName.toLowerCase()!='a'){src=src.parentNode;}if(src==null){if(svg.wnd!=null&amp;&amp;!svg.wnd.closed){svg.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&amp;&amp;evt.source==svg.wnd){svg.wnd.postMessage(decodeURIComponent(svg.getAttribute('content')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);svg.wnd=window.open('https://www.draw.io/?client=1&amp;lightbox=1&amp;edit=_blank');}}})(this);" style="cursor:pointer;max-width:100%;max-height:263px;"><defs/><g><path d="M 127 33 L 367 33" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 54px; margin-left: 248px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia">e<sup>-</sup></font></div></div></div></foreignObject><text x="248" y="61" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">e-</text></switch></g><path d="M 127 233 L 367 233" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 7 253 L 7 19.37" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 7 14.12 L 10.5 21.12 L 7 19.37 L 3.5 21.12 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 130px; margin-left: 8px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><i><font face="Georgia">ε</font></i></div></div></div></foreignObject><text x="8" y="137" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">ε</text></switch></g><path d="M 67 246.63 L 67 19.37" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 67 251.88 L 63.5 244.88 L 67 246.63 L 70.5 244.88 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><path d="M 67 14.12 L 70.5 21.12 L 67 19.37 L 63.5 21.12 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 133px; margin-left: 67px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><i><font face="Georgia">E</font></i></div></div></div></foreignObject><text x="67" y="140" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">E</text></switch></g><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 244px; margin-left: 48px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia">+</font></div></div></div></foreignObject><text x="48" y="251" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">+</text></switch></g><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 14px; margin-left: 48px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia">-</font></div></div></div></foreignObject><text x="48" y="21" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">-</text></switch></g><path d="M 207 53 L 207 204.76" fill="none" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 207 210.76 L 203 202.76 L 207 204.76 L 211 202.76 Z" fill="#000000" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 124px; margin-left: 148px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 18px">spontaneous:<br />battery<br /></font></div></div></div></foreignObject><text x="148" y="131" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">spontaneous:...</text></switch></g><path d="M 287 213 L 287 61.24" fill="none" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 287 55.24 L 291 63.24 L 287 61.24 L 283 63.24 Z" fill="#000000" stroke="#000000" stroke-width="2" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 124px; margin-left: 368px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 24px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 18px">non-spontaneous:<br />electrolysis</font></div></div></div></foreignObject><text x="368" y="131" fill="#000000" font-family="Helvetica" font-size="24px" text-anchor="middle">non-spontaneous:...</text></switch></g></g><switch><g requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"/><a transform="translate(0,-5)" xlink:href="https://desk.draw.io/support/solutions/articles/16000042487" target="_blank"><text text-anchor="middle" font-size="10px" x="50%" y="100%">Viewer does not support full SVG 1.1</text></a></switch></svg>

# %%
#@title 電子授受平行のイメージ
# %%svg
<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="498px" viewBox="-0.5 -0.5 498 380" content="&lt;mxfile host=&quot;app.diagrams.net&quot; modified=&quot;2020-06-03T20:00:03.503Z&quot; agent=&quot;5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36&quot; etag=&quot;IB7cj82XMoBF4r77unq2&quot; version=&quot;13.1.6&quot; type=&quot;google&quot;&gt;&lt;diagram id=&quot;PlZGskYz1EdZYBw5iLk9&quot; name=&quot;Page-1&quot;&gt;...&lt;/diagram&gt;&lt;/mxfile&gt;" onclick="(function(svg){var src=window.event.target||window.event.srcElement;while (src!=null&amp;&amp;src.nodeName.toLowerCase()!='a'){src=src.parentNode;}if(src==null){if(svg.wnd!=null&amp;&amp;!svg.wnd.closed){svg.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&amp;&amp;evt.source==svg.wnd){svg.wnd.postMessage(decodeURIComponent(svg.getAttribute('content')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);svg.wnd=window.open('https://app.diagrams.net/?client=1&amp;lightbox=1&amp;edit=_blank');}}})(this);" style="cursor:pointer;max-width:100%;max-height:380px;"><defs/><g><path d="M 36 331.63 L 36 104.37" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 36 336.88 L 32.5 329.88 L 36 331.63 L 39.5 329.88 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><path d="M 36 99.12 L 39.5 106.12 L 36 104.37 L 32.5 106.12 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 350px; margin-left: 37px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 18px">+</font></div></div></div></foreignObject><text x="37" y="353" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">+</text></switch></g><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 86px; margin-left: 36px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 18px">-</font></div></div></div></foreignObject><text x="36" y="89" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">-</text></switch></g><rect x="76" y="98" width="120" height="60" fill="#ffffff" stroke="#000000" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 128px; margin-left: 77px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia" style="font-size: 12px">Conduction<sub>-</sub></font></div></div></div></foreignObject><text x="136" y="132" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Conduction-</text></switch></g><rect x="76" y="158" width="120" height="100" fill="#f5f5f5" stroke="#666666" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 208px; margin-left: 77px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #333333; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font style="font-size: 12px" face="Georgia">Valence<sub>-</sub></font></div></div></div></foreignObject><text x="136" y="212" fill="#333333" font-family="Helvetica" font-size="12px" text-anchor="middle">Valence-</text></switch></g><path d="M 196 378 L 196 58" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 356 378 L 356 58" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><rect x="356" y="178" width="120" height="60" fill="#ffffff" stroke="#000000" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 208px; margin-left: 357px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia">Conduction<sub>+</sub></font></div></div></div></foreignObject><text x="416" y="212" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Conduction+</text></switch></g><rect x="356" y="238" width="120" height="100" fill="#f5f5f5" stroke="#666666" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 288px; margin-left: 357px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #333333; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; ">Valence<sub>+</sub></div></div></div></foreignObject><text x="416" y="292" fill="#333333" font-family="Helvetica" font-size="12px" text-anchor="middle">Valence+</text></switch></g><path d="M 76 158 L 196 158" fill="none" stroke="#000000" stroke-width="3" stroke-miterlimit="10" pointer-events="stroke"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 159px; margin-left: 137px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 12px" face="Georgia"><i>E</i><sub>F-</sub></font></div></div></div></foreignObject><text x="137" y="162" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">EF-</text></switch></g><path d="M 356 238 L 476 238" fill="none" stroke="#000000" stroke-width="3" stroke-miterlimit="10" pointer-events="stroke"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 239px; margin-left: 417px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia"><i>E</i><font size="1"><sub>F+</sub></font></font></div></div></div></foreignObject><text x="417" y="242" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">EF+</text></switch></g><path d="M 476 238 L 486 238 Q 496 238 496 228 L 496 48 Q 496 38 486 38 L 66 38 Q 56 38 56 48 L 56 148 Q 56 158 66 158 L 76 158" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 236.5 33 L 236.5 23 L 296.5 23 L 296.5 12.5 L 315.5 28 L 296.5 43.5 L 296.5 33 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 9px; margin-left: 277px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 12px">e<sup>-</sup></font></div></div></div></foreignObject><text x="277" y="12" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">e-</text></switch></g><path d="M 276 178 L 246 178 Q 236 178 236 168 L 236 163 Q 236 158 226 158 L 202.37 158" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 197.12 158 L 204.12 154.5 L 202.37 158 L 204.12 161.5 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 179px; margin-left: 279px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 12px" face="Georgia">R</font></div></div></div></foreignObject><text x="279" y="182" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">R</text></switch></g><path d="M 269.63 138 L 246 138 Q 236 138 236 148 L 236 153 Q 236 158 226 158 L 196 158" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="3 3" pointer-events="stroke"/><path d="M 274.88 138 L 267.88 141.5 L 269.63 138 L 267.88 134.5 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 139px; margin-left: 281px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia">O</font></div></div></div></foreignObject><text x="281" y="142" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">O</text></switch></g><path d="M 282.37 258 L 306 258 Q 316 258 316 248 L 316 243 Q 316 238 326 238 L 356 238" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 277.12 258 L 284.12 254.5 L 282.37 258 L 284.12 261.5 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 259px; margin-left: 270px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 12px">R'</font></div></div></div></foreignObject><text x="270" y="262" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">R'</text></switch></g><path d="M 276 218 L 306 218 Q 316 218 316 227.5 L 316 232.25 Q 316 237 326 237 L 349.63 237" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="3 3" pointer-events="stroke"/><path d="M 354.88 237 L 347.88 240.5 L 349.63 237 L 347.88 233.5 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 218px; margin-left: 269px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 12px">O'</font></div></div></div></foreignObject><text x="269" y="221" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">O'</text></switch></g><rect x="226" y="318" width="110" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 328px; margin-left: 281px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: nowrap; "><font face="Georgia">aqueous solution</font></div></div></div></foreignObject><text x="281" y="332" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">aqueous solution</text></switch></g><path d="M 21 218.5 L 31.5 218.5 L 16 237.5 L 0.5 218.5 L 11 218.5 L 11 177.5 L 0.5 177.5 L 16 158.5 L 31.5 177.5 L 21 177.5 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" pointer-events="all"/></g><switch><g requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"/><a transform="translate(0,-5)" xlink:href="https://desk.draw.io/support/solutions/articles/16000042487" target="_blank"><text text-anchor="middle" font-size="10px" x="50%" y="100%">Viewer does not support full SVG 1.1</text></a></switch></svg>

# %%
#@title 実際の装置の概念図(5が対象となる電極へ)
# %%svg
https://upload.wikimedia.org/wikipedia/commons/5/59/Standard_hydrogen_electrode_2009-02-06.svg

# %% [markdown]
# ### $E^\circ$ 値の計算
#
# \begin{align*}
# \ce{Zn(OH)2 + 2e- &<=> Zn + 2OH-} &\\
# \Delta_{\rm f}G^\circ(\ce{Zn(OH)2})
# + (-2\mathcal{F})E^\circ
# &= \Delta_{\rm f}G^\circ(\ce{Zn})
# + 2\Delta_{\rm f}G^\circ(\ce{OH-})&
# \end{align*}

# %%
#@title 付録1を利用して計算すると
dfG_ZnOH2=-555*10**3
dfG_Zn=0*10**3
dfG_OH=-157*10**3
q=2*96500
E0 = - (dfG_ZnOH2-dfG_Zn-2*dfG_OH)/q
print(E0)
# Out:
# 1.2487046632124352

# %% [markdown]
# $E^\circ = {\rm 1.25\ V}\ vs. {\rm SHE}$

# %% [markdown]
# ### エネルギー軸と電位軸: 具体例

# %%
#@title Daniell cell
# %%svg
https://upload.wikimedia.org/wikipedia/commons/a/a5/Galvanic_cell_labeled.svg

# %% [markdown]
# 負極
# \begin{align*}
# \ce{Zn^2+}:&\Delta_f G^\circ(\ce{Zn^2+})= {\rm -147\ kJ} <0&\\
# \ce{Zn^2+  + 2 e- &<=> Zn} \qquad E^\circ = {\rm -0.76\ V}&
# \end{align*}
#
# 正極
# \begin{align*}
# \ce{Cu^2+}:&\Delta_f G^\circ(\ce{Cu^2+})= {\rm +65\ kJ} >0&\\
# \ce{Cu^2+  + 2 e- &<=> Cu} \qquad E^\circ = {\rm +0.34\ V}&
# \end{align*}
#
# 電池反応
# \begin{align*}
# \ce{Zn + Cu^2+ &\to Zn^2+ + Cu} \qquad E^\circ = {\rm 1.10\ V}&
# \end{align*}

# %%
#@title ダニエル電池の電子授受平行
# %%svg
<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" width="505px" viewBox="-0.5 -0.5 505 271" content="&lt;mxfile host=&quot;app.diagrams.net&quot; modified=&quot;2020-06-03T19:58:27.930Z&quot; agent=&quot;5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36&quot; etag=&quot;QXe6kfjBbqjCSmS3oTww&quot; version=&quot;13.1.6&quot; type=&quot;google&quot;&gt;&lt;diagram id=&quot;uyoWFRe2RqD5K6WbbjI0&quot; name=&quot;Page-1&quot;&gt;...&lt;/diagram&gt;&lt;/mxfile&gt;" onclick="(function(svg){var src=window.event.target||window.event.srcElement;while (src!=null&amp;&amp;src.nodeName.toLowerCase()!='a'){src=src.parentNode;}if(src==null){if(svg.wnd!=null&amp;&amp;!svg.wnd.closed){svg.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&amp;&amp;evt.source==svg.wnd){svg.wnd.postMessage(decodeURIComponent(svg.getAttribute('content')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);svg.wnd=window.open('https://app.diagrams.net/?client=1&amp;lightbox=1&amp;edit=_blank');}}})(this);" style="cursor:pointer;max-width:100%;max-height:271px;"><defs/><g><path d="M 487 182 L 53 182" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="stroke"/><path d="M 483 72 L 53 72" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="stroke"/><path d="M 23 256 L 23 22.37" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><path d="M 23 17.12 L 26.5 24.12 L 23 22.37 L 19.5 24.12 Z" fill="#000000" stroke="#000000" stroke-miterlimit="10" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 7px; margin-left: 23px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 12px" face="Georgia">Δ<i>G</i></font></div></div></div></foreignObject><text x="23" y="10" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">ΔG</text></switch></g><path d="M 63 256 L 63 16" fill="none" stroke="#000000" stroke-miterlimit="10" pointer-events="stroke"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 96px; margin-left: 53px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 18px" face="Georgia"><i>E</i></font></div></div></div></foreignObject><text x="53" y="99" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">E</text></switch></g><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 264px; margin-left: 63px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 12px" face="Georgia">+</font></div></div></div></foreignObject><text x="63" y="267" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">+</text></switch></g><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 7px; margin-left: 64px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font face="Georgia" style="font-size: 12px">-</font></div></div></div></foreignObject><text x="64" y="10" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">-</text></switch></g><path d="M 503 136 L 13 136" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="3 3" pointer-events="stroke"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 1px; height: 1px; padding-top: 136px; margin-left: 4px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 11px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; background-color: #ffffff; white-space: nowrap; "><font style="font-size: 12px" face="Georgia">0</font></div></div></div></foreignObject><text x="4" y="139" fill="#000000" font-family="Helvetica" font-size="11px" text-anchor="middle">0</text></switch></g><rect x="103" y="116" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 126px; margin-left: 104px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia"><font color="#cccccc">Zn<sup>2+</sup> + 2e<sup>-</sup></font> = Zn</font></div></div></div></foreignObject><text x="163" y="130" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Zn2+ + 2e- = Zn</text></switch></g><rect x="303" y="116" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 126px; margin-left: 304px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia"><font color="#cccccc">Cu<sup>2+</sup> + 2e<sup>-</sup></font> = Cu</font></div></div></div></foreignObject><text x="363" y="130" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Cu2+ + 2e- = Cu</text></switch></g><rect x="73" y="196" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 206px; margin-left: 74px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia">Zn<sup>2+</sup></font></div></div></div></foreignObject><text x="133" y="210" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Zn2+</text></switch></g><rect x="109" y="56" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 66px; margin-left: 110px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia">2e<sup>-</sup></font></div></div></div></foreignObject><text x="169" y="70" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">2e-</text></switch></g><rect x="275" y="86" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 96px; margin-left: 276px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia">Cu<sup>2+</sup> </font></div></div></div></foreignObject><text x="335" y="100" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle">Cu2+ </text></switch></g><rect x="308" y="162" width="120" height="20" fill="none" stroke="none" pointer-events="all"/><g transform="translate(-0.5 -0.5)"><switch><foreignObject style="overflow: visible; text-align: left;" pointer-events="none" width="100%" height="100%" requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"><div xmlns="http://www.w3.org/1999/xhtml" style="display: flex; align-items: unsafe center; justify-content: unsafe center; width: 118px; height: 1px; padding-top: 172px; margin-left: 309px;"><div style="box-sizing: border-box; font-size: 0; text-align: center; "><div style="display: inline-block; font-size: 12px; font-family: Helvetica; color: #000000; line-height: 1.2; pointer-events: all; white-space: normal; word-wrap: normal; "><font face="Georgia"> 2e<sup>-</sup></font></div></div></div></foreignObject><text x="368" y="176" fill="#000000" font-family="Helvetica" font-size="12px" text-anchor="middle"> 2e-</text></switch></g><path d="M 97 136.5 L 107 136.5 L 107 196.5 L 117.5 196.5 L 102 215.5 L 86.5 196.5 L 97 196.5 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="all"/><path d="M 428 135.5 L 418 135.5 L 418 125.5 L 407.5 125.5 L 423 106.5 L 438.5 125.5 L 428 125.5 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="all"/><path d="M 313 106 L 273 106" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="stroke"/><path d="M 253 216 L 213 216" fill="none" stroke="#000000" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="stroke"/><path d="M 268 196.5 L 278.5 196.5 L 263 215.5 L 247.5 196.5 L 258 196.5 L 258 125.5 L 247.5 125.5 L 263 106.5 L 278.5 125.5 L 268 125.5 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" stroke-dasharray="1 1" pointer-events="all"/><path d="M 468 162.5 L 478.5 162.5 L 463 181.5 L 447.5 162.5 L 458 162.5 L 458 91.5 L 447.5 91.5 L 463 72.5 L 478.5 91.5 L 468 91.5 Z" fill="none" stroke="#000000" stroke-linejoin="round" stroke-miterlimit="10" pointer-events="all"/></g><switch><g requiredFeatures="http://www.w3.org/TR/SVG11/feature#Extensibility"/><a transform="translate(0,-5)" xlink:href="https://desk.draw.io/support/solutions/articles/16000042487" target="_blank"><text text-anchor="middle" font-size="10px" x="50%" y="100%">Viewer does not support full SVG 1.1</text></a></switch></svg>
